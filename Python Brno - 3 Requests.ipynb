# %% [markdown]
# # Requests
#
# ## Types of requests
#
# ### POST
# The POST verb is most-often utilized to **create** new resources. In particular, it's used to create subordinate resources. That is, subordinate to some other (e.g. parent) resource. In other words, when creating a new resource, POST to the parent and the service takes care of associating the new resource with the parent, assigning an ID (new resource URI), etc.
#
# Example:
# <pre>POST http://www.example.com/customers/12345/orders</pre>
#
#
# ### GET
# The HTTP GET method is used to **read** (or retrieve) a representation of a resource. In the “happy” (or non-error) path, GET returns a representation in XML or JSON and an HTTP response code of 200 (OK). In an error case, it most often returns a 404 (NOT FOUND) or 400 (BAD REQUEST).
#
# Example:
# <pre>GET http://www.example.com/customers/12345</pre>
#
# ### PUT
# PUT is most-often utilized for **update** capabilities, PUT-ing to a known resource URI with the request body containing the newly-updated representation of the original resource.
#
# However, PUT can also be used to create a resource in the case where the resource ID is chosen by the client instead of by the server. In other words, if the PUT is to a URI that contains the value of a non-existent resource ID. Again, the request body contains a resource representation. Many feel this is convoluted and confusing. Consequently, this method of creation should be used sparingly, if at all.
#
# Example:
# <pre>PUT http://www.example.com/customers/12345/orders/98765</pre>
#
# ### PATCH
# PATCH is used for **modify** capabilities. The PATCH request only needs to contain the changes to the resource, not the complete resource.
#
# This resembles PUT, but the body contains a set of instructions describing how a resource currently residing on the server should be modified to produce a new version. This means that the PATCH body should not just be a modified part of the resource, but in some kind of patch language like JSON Patch or XML Patch.
#
# Example:
# <pre>PATCH http://www.example.com/customers/12345/orders/98765</pre>
#
# ### DELETE
# DELETE is pretty easy to understand. It is used to **delete** a resource identified by a URI.
#
# Example:
# <pre>DELETE http://www.example.com/customers/12345</pre>
#
# ## Introduction to python requests
# Requests is an elegant and simple HTTP library for Python, built for human beings.
#
# http://docs.python-requests.org/en/master/user/quickstart/
#
# ### Installation
#
# <pre>pip install requests</pre>

# %% [markdown]
# ### Usage
#
# Making a request with Requests is very simple.<br/>
# Begin by importing the Requests module:

# %%
import requests

# %% [markdown]
# Now, let's try to get a webpage. For this example, let's get GitHub's public timeline:

# %%
r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Brno')
print(r.text)
# Out:
# {"cod":401, "message": "Invalid API key. Please see http://openweathermap.org/faq#error401 for more info."}

# %%
r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Brno&appid=bf64595051e349758a7f72cae0544cbf')
data = json.loads(r.text)
print(json.dumps(data, indent=4))
# Out:
# {
#     "coord": {
#         "lon": 16.61,
#         "lat": 49.2
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 272.61,
#         "pressure": 1018,
#         "humidity": 82,
#         "temp_min": 272.15,
#         "temp_max": 273.15
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.6,
#         "deg": 50
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1486483200,
#     "sys": {
#         "type": 1,
#         "id": 5899,
#         "message": 0.0023,
#         "country": "CZ",
#         "sunrise": 1486448075,
#         "sunset": 1486483293
#     },
#     "id": 3078610,
#     "name": "Brno",
#     "cod": 200
# }

# %% [markdown]
# ### Raw Response Content
#
# In the rare case that you'd like to get the raw response from the server, you can access `r.raw`. If you want to do this, make sure you set `stream=True` in your initial request.
#
# This is used to download files from web to your disk for further use.

# %%
r = requests.get('https://api.github.com/events', stream=True)
r.raw.read(10)
# Out:
# b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03'

# %% [markdown]
# #### Lorempixel example:
# http://lorempixel.com/g/400/300/cats/

# %%
r = requests.get('http://lorempixel.com/g/400/300/cats/', stream=True)
with open("sample.png", 'wb') as fd:
    for chunk in r.iter_content(chunk_size=128):
        fd.write(chunk)

# %% [markdown]
# ## POST example
# RequestBin gives you a URL that will collect requests made to it and let you inspect them in a human-friendly way.
# Use RequestBin to see what your HTTP client is sending or to inspect and debug webhook requests.
#
# https://requestb.in/

# %%
import time
r = requests.post('http://requestb.in/ti0lagti', data={"ts":time.time(),"message":"Hello from Hub"})
print(r.status_code)
print(r.content)
# Out:
# 200
# b'ok'

# %% [markdown]
# ## Transparent bank accounts (ČS)
# Sandbox Transparent Accounts API provides REST API interface designed for an access to information about ČS, a.s. transparent accounts and transactions on them.
#
# https://developers.csas.cz/docs/transparent-account#/reference/basic-mechanisms

# %%
import json
r = requests.get('https://api.csas.cz/sandbox/webapi/api/v2/transparentAccounts?WEB-API-key=6abcbddc-8d24-4178-a26f-c3ff2960fb28')
data = json.loads(r.text)
print(json.dumps(data, indent=4))
# Out:
# {
#     "pageNumber": 0,
#     "pageSize": 50,
#     "pageCount": 5,
#     "nextPage": 1,
#     "recordCount": 228,
#     "accounts": [
#         {
#             "accountNumber": "000000-0109213309",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-01-24T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:01:05",
#             "balance": 593577.94,
#             "currency": "CZK",
#             "name": "Spole\u010denstv\u00ed Praha 4, Ob\u011bt\u00ed 6.kv\u011btna 553",
#             "iban": "CZ75 0800 0000 0001 0921 3309"
#         },
#         {
#             "accountNumber": "000000-2824570013",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-01-14T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-01-31T20:00:48",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "Magdalena M\u011bkynov\u00e1",
#             "iban": "CZ53 0800 0000 0028 2457 0013"
#         },
#         {
#             "accountNumber": "000000-0460043319",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-04-08T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:01:29",
#             "balance": 2552299.68,
#             "currency": "CZK",
#             "name": "Obec Nov\u00e1 Ves",
#             "iban": "CZ63 0800 0000 0004 6004 3319"
#         },
#         {
#             "accountNumber": "000000-3936173359",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-04-10T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:01:32",
#             "balance": 1444.02,
#             "currency": "CZK",
#             "name": "\u010cSOP - RS IRIS",
#             "iban": "CZ19 0800 0000 0039 3617 3359"
#         },
#         {
#             "accountNumber": "000000-1360597319",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-04-17T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:01:43",
#             "balance": 2218236.29,
#             "currency": "CZK",
#             "name": "Obec Kuni\u010dky",
#             "iban": "CZ53 0800 0000 0013 6059 7319"
#         },
#         {
#             "accountNumber": "000027-2000709369",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-04-01T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:01",
#             "balance": 2271648.53,
#             "currency": "CZK",
#             "name": "M\u011bstsk\u00e1 \u010d\u00e1st Praha 21",
#             "iban": "CZ21 0800 0000 2720 0070 9369"
#         },
#         {
#             "accountNumber": "000000-2932683103",
#             "bankCode": "0800",
#             "transparencyFrom": "2016-03-21T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:03",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "Petr Pelik\u00e1n",
#             "iban": "CZ21 0800 0000 0029 3268 3103"
#         },
#         {
#             "accountNumber": "000000-4124895369",
#             "bankCode": "0800",
#             "transparencyFrom": "2016-03-18T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:04",
#             "balance": 3083.6,
#             "currency": "CZK",
#             "name": "Sdru\u017een\u00ed rodi\u010d\u016f Z\u0160 \u017dd\u00edrec nad Doubravou",
#             "iban": "CZ42 0800 0000 0041 2489 5369"
#         },
#         {
#             "accountNumber": "000000-2933242123",
#             "bankCode": "0800",
#             "transparencyFrom": "2016-03-23T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:05",
#             "balance": 995.14,
#             "currency": "CZK",
#             "name": "\u0160t\u011bp\u00e1n Korbel",
#             "iban": "CZ69 0800 0000 0029 3324 2123"
#         },
#         {
#             "accountNumber": "000182-0388063349",
#             "bankCode": "0800",
#             "transparencyFrom": "2013-12-18T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:08",
#             "balance": 36899.76,
#             "currency": "CZK",
#             "name": "M\u011bsto \u010cerno\u0161ice",
#             "description": "Ve\u0159ejn\u00e1 sb\u00edrka - sportovn\u00ed hala",
#             "iban": "CZ07 0800 0001 8203 8806 3349"
#         },
#         {
#             "accountNumber": "000000-3643062399",
#             "bankCode": "0800",
#             "transparencyFrom": "2014-07-10T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2016-03-24T22:01:49",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "Polsk\u00fd kulturn\u011b-osv\u011btov\u00fd svaz v \u010cesk\u00e9 republice",
#             "iban": "CZ97 0800 0000 0036 4306 2399"
#         },
#         {
#             "accountNumber": "000000-3682094369",
#             "bankCode": "0800",
#             "transparencyFrom": "2014-07-22T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:10",
#             "balance": 45934.07,
#             "currency": "CZK",
#             "name": "Podpora ob\u010dan\u016f",
#             "iban": "CZ03 0800 0000 0036 8209 4369"
#         },
#         {
#             "accountNumber": "000000-2857435053",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-06-03T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-01-31T20:02:14",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "Eva Sk\u0159ebsk\u00e1 ",
#             "iban": "CZ70 0800 0000 0028 5743 5053"
#         },
#         {
#             "accountNumber": "000000-2857059123",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-06-03T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:11",
#             "balance": 20824.9,
#             "currency": "CZK",
#             "name": "Romana Markov\u00e1",
#             "iban": "CZ03 0800 0000 0028 5705 9123"
#         },
#         {
#             "accountNumber": "000000-2192739123",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-06-09T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:13",
#             "balance": 4259.73,
#             "currency": "CZK",
#             "name": "Krist\u00fdna Zaklov\u00e1",
#             "iban": "CZ45 0800 0000 0021 9273 9123"
#         },
#         {
#             "accountNumber": "000000-4016445379",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-06-23T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:14",
#             "balance": 20100.31,
#             "currency": "CZK",
#             "name": "Letn\u00ed filosofick\u00e1 \u0161kola",
#             "iban": "CZ05 0800 0000 0040 1644 5379"
#         },
#         {
#             "accountNumber": "000000-3868885329",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-07-27T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-01-16T22:02:54",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "Na nohou bez nohou, z.s.",
#             "iban": "CZ03 0800 0000 0038 6888 5329"
#         },
#         {
#             "accountNumber": "000027-2000700399",
#             "bankCode": "0800",
#             "transparencyFrom": "2014-06-20T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:49",
#             "balance": 2084791.57,
#             "currency": "CZK",
#             "name": "M\u011bstsk\u00e1 \u010d\u00e1st Praha 17",
#             "iban": "CZ02 0800 0000 2720 0070 0399"
#         },
#         {
#             "accountNumber": "000000-3617949359",
#             "bankCode": "0800",
#             "transparencyFrom": "2014-06-12T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-01-26T22:02:03",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "Asociace prodejc\u016f barev \u010cesk\u00e9 republiky o.s.",
#             "iban": "CZ61 0800 0000 0036 1794 9359"
#         },
#         {
#             "accountNumber": "000000-1667365379",
#             "bankCode": "0800",
#             "transparencyFrom": "2014-09-01T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:54",
#             "balance": 270.84,
#             "currency": "CZK",
#             "name": "KLACR o.s.",
#             "iban": "CZ89 0800 0000 0016 6736 5379"
#         },
#         {
#             "accountNumber": "000000-3824812339",
#             "bankCode": "0800",
#             "transparencyFrom": "2014-11-04T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:02:56",
#             "balance": 1001.05,
#             "currency": "CZK",
#             "name": "Slov\u00e1ck\u00fd b\u011b\u017eeck\u00fd klub Kyjov, o.s.",
#             "iban": "CZ50 0800 0000 0038 2481 2339"
#         },
#         {
#             "accountNumber": "000000-1846405399",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-04-01T00:00:00",
#             "transparencyTo": "2018-10-31T00:00:00",
#             "publicationTo": "2018-10-31T00:00:00",
#             "actualizationDate": "2017-02-07T16:03:15",
#             "balance": 16234909.75,
#             "currency": "CZK",
#             "name": "Obec Branka u Opavy",
#             "iban": "CZ06 0800 0000 0018 4640 5399"
#         },
#         {
#             "accountNumber": "000000-3095566309",
#             "bankCode": "0800",
#             "transparencyFrom": "2016-08-20T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:03:25",
#             "balance": 11057.42,
#             "currency": "CZK",
#             "name": "Sdru\u017een\u00ed Neratov",
#             "iban": "CZ84 0800 0000 0030 9556 6309"
#         },
#         {
#             "accountNumber": "000000-0003225002",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-04-01T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:03:26",
#             "balance": 6258458.65,
#             "name": "M\u011bsto Mari\u00e1nsk\u00e9 L\u00e1zn\u011b",
#             "iban": "CZ64 0800 0000 0000 0322 5002"
#         },
#         {
#             "accountNumber": "000000-2842984033",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-03-24T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2016-08-31T20:04:34",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "Radek Mahrla",
#             "iban": "CZ57 0800 0000 0028 4298 4033"
#         },
#         {
#             "accountNumber": "000000-4045780379",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-04-08T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:03:28",
#             "balance": 4994.01,
#             "currency": "CZK",
#             "name": " Asociace muskul\u00e1rn\u00edch dystrofik\u016f v \u010cR- ob\u010dansk\u00e9 sdru\u017een\u00ed",
#             "iban": "CZ66 0800 0000 0040 4578 0379"
#         },
#         {
#             "accountNumber": "000000-4049930389",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-05-14T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:03:39",
#             "balance": 68689.07,
#             "currency": "CZK",
#             "name": "AZYL PRO OPU\u0160T\u011aN\u00c9 KO\u010cKY 'LUCKY'",
#             "iban": "CZ25 0800 0000 0040 4993 0389"
#         },
#         {
#             "accountNumber": "000000-4007514379",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-05-13T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:03:41",
#             "balance": 1561.76,
#             "currency": "CZK",
#             "name": "TJ SOKOL N\u011aM\u010cI\u010cKY",
#             "iban": "CZ49 0800 0000 0040 0751 4379"
#         },
#         {
#             "accountNumber": "000000-0388041369",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-07-08T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:04:28",
#             "balance": 21362445.18,
#             "currency": "CZK",
#             "name": "M\u011bsto Roztoky 1",
#             "iban": "CZ53 0800 0000 0003 8804 1369"
#         },
#         {
#             "accountNumber": "000019-0388041369",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-07-08T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:04:59",
#             "balance": 6269020.75,
#             "currency": "CZK",
#             "name": "M\u011bsto Roztoky 2",
#             "iban": "CZ39 0800 0000 1903 8804 1369"
#         },
#         {
#             "accountNumber": "000000-2888974033",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-09-24T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:03",
#             "balance": 55504.53,
#             "currency": "CZK",
#             "name": "Erika Beranov\u00e1",
#             "iban": "CZ37 0800 0000 0028 8897 4033"
#         },
#         {
#             "accountNumber": "000000-2926061033",
#             "bankCode": "0800",
#             "transparencyFrom": "2016-02-05T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:08",
#             "balance": 137757.11,
#             "currency": "CZK",
#             "name": "Jan Dost\u00e1l",
#             "iban": "CZ79 0800 0000 0029 2606 1033"
#         },
#         {
#             "accountNumber": "000000-4121261379",
#             "bankCode": "0800",
#             "transparencyFrom": "2016-02-15T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:11",
#             "balance": 1096.49,
#             "currency": "CZK",
#             "name": "VeseLESem, z.s. ",
#             "iban": "CZ41 0800 0000 0041 2126 1379"
#         },
#         {
#             "accountNumber": "000000-0077778822",
#             "bankCode": "0800",
#             "transparencyFrom": "2013-09-01T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:13",
#             "balance": 5792.73,
#             "name": "\u017didovsk\u00e1 obec v Praze",
#             "description": "D\u00edlna Becalel",
#             "iban": "CZ42 0800 0000 0000 7777 8822"
#         },
#         {
#             "accountNumber": "000000-3675616309",
#             "bankCode": "0800",
#             "transparencyFrom": "2014-07-01T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:15",
#             "balance": 6290.16,
#             "currency": "CZK",
#             "name": "NOV\u00dd SEVER",
#             "iban": "CZ36 0800 0000 0036 7561 6309"
#         },
#         {
#             "accountNumber": "000000-2822226083",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-01-16T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:16",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "Bc. Adam Pt\u00e1\u010dek ",
#             "description": "(Pink Carpet: Helping Dolls)",
#             "iban": "CZ65 0800 0000 0028 2222 6083"
#         },
#         {
#             "accountNumber": "000000-3758555329",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-01-22T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:17",
#             "balance": 2113.73,
#             "currency": "CZK",
#             "name": "Z\u00e1kladn\u00ed \u0161kola Br\u00e1na jazyk\u016f",
#             "iban": "CZ39 0800 0000 0037 5855 5329"
#         },
#         {
#             "accountNumber": "020183-0388949369",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-10-09T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:18",
#             "balance": 65122.41,
#             "currency": "CZK",
#             "name": "SVAZEK OBC\u00cd - REGION DOLN\u00cd BEROUNKA",
#             "iban": "CZ78 0800 0201 8303 8894 9369"
#         },
#         {
#             "accountNumber": "000182-0388949369",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-10-09T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:19",
#             "balance": 60375.24,
#             "currency": "CZK",
#             "name": "SVAZEK OBC\u00cd - REGION DOLN\u00cd BEROUNKA",
#             "iban": "CZ92 0800 0001 8203 8894 9369"
#         },
#         {
#             "accountNumber": "030189-0388949369",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-10-09T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:19",
#             "balance": 4327.42,
#             "currency": "CZK",
#             "name": "SVAZEK OBC\u00cd - REGION DOLN\u00cd BEROUNKA",
#             "iban": "CZ21 0800 0301 8903 8894 9369"
#         },
#         {
#             "accountNumber": "000000-3575206329",
#             "bankCode": "0800",
#             "transparencyFrom": "2014-08-14T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2016-03-04T20:07:32",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "Martin Burs\u00edk",
#             "iban": "CZ06 0800 0000 0035 7520 6329"
#         },
#         {
#             "accountNumber": "000000-2811533053",
#             "bankCode": "0800",
#             "transparencyFrom": "2014-11-10T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:22",
#             "balance": 55988.18,
#             "currency": "CZK",
#             "name": "Tom\u00e1\u0161 Zbr\u00e1nek",
#             "iban": "CZ08 0800 0000 0028 1153 3053"
#         },
#         {
#             "accountNumber": "000000-3737631329",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-02-10T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:24",
#             "balance": 1225.86,
#             "currency": "CZK",
#             "name": "23/02 ZO \u010cSOP Berkut",
#             "iban": "CZ57 0800 0000 0037 3763 1329"
#         },
#         {
#             "accountNumber": "000000-2829895183",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-02-02T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:25",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "Ale\u0161 Jir\u00e1sek",
#             "iban": "CZ71 0800 0000 0028 2989 5183"
#         },
#         {
#             "accountNumber": "000000-0006189422",
#             "bankCode": "0800",
#             "transparencyFrom": "2014-09-17T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:28",
#             "balance": 104110.33,
#             "name": " Nada\u010dn\u00ed fond Evy Mat\u011bjkov\u00e9",
#             "iban": "CZ80 0800 0000 0000 0618 9422"
#         },
#         {
#             "accountNumber": "000019-0580424319",
#             "bankCode": "0800",
#             "transparencyFrom": "2015-08-31T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:30",
#             "balance": 157142.0,
#             "currency": "CZK",
#             "name": "\u0158\u00edmskokatolick\u00e1 farnost K\u0159em\u017ee",
#             "iban": "CZ10 0800 0000 1905 8042 4319"
#         },
#         {
#             "accountNumber": "000000-2937537113",
#             "bankCode": "0800",
#             "transparencyFrom": "2016-04-15T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:30",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "\u017daneta Krskov\u00e1",
#             "iban": "CZ03 0800 0000 0029 3753 7113"
#         },
#         {
#             "accountNumber": "000000-2936934053",
#             "bankCode": "0800",
#             "transparencyFrom": "2016-04-08T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:31",
#             "balance": 0.0,
#             "currency": "CZK",
#             "name": "Marie Pro\u0161kov\u00e1",
#             "description": "sb\u00edrka pro Nep\u00e1l",
#             "iban": "CZ09 0800 0000 0029 3693 4053"
#         },
#         {
#             "accountNumber": "000000-2935812193",
#             "bankCode": "0800",
#             "transparencyFrom": "2016-04-06T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:32",
#             "balance": 16444.32,
#             "currency": "CZK",
#             "name": "T\u00fdna Buben\u00ed\u010dkov\u00e1",
#             "iban": "CZ39 0800 0000 0029 3581 2193"
#         },
#         {
#             "accountNumber": "000000-2003844339",
#             "bankCode": "0800",
#             "transparencyFrom": "2013-09-09T00:00:00",
#             "transparencyTo": "3000-01-01T00:00:00",
#             "publicationTo": "3000-01-01T00:00:00",
#             "actualizationDate": "2017-02-07T16:05:34",
#             "balance": 38736.5,
#             "currency": "CZK",
#             "name": "M\u011bstsk\u00e1 \u010d\u00e1st Praha 7",
#             "iban": "CZ93 0800 0000 0020 0384 4339"
#         }
#     ]
# }

# %%
r = requests.get('https://api.csas.cz/sandbox/webapi/api/v2/transparentAccounts/000000-0460043319/transactions?WEB-API-key=6abcbddc-8d24-4178-a26f-c3ff2960fb28')
data = json.loads(r.text)
print(json.dumps(data, indent=4))
# Out:
# {
#     "pageNumber": 0,
#     "pageSize": 50,
#     "pageCount": 34,
#     "nextPage": 1,
#     "recordCount": 1677,
#     "transactions": [
#         {
#             "amount": {
#                 "value": 1584.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "80110",
#             "dueDate": "2016-01-18T00:00:00",
#             "processingDate": "2016-01-18T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0193366542",
#                 "bankCode": "0600",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "472015",
#                 "constantSymbol": "0",
#                 "name": "FRANTI\u0160EK POL\u00c1\u010cEK",
#                 "description": "sto\u010dn\u00e9"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": 1188.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "80110",
#             "dueDate": "2016-01-18T00:00:00",
#             "processingDate": "2016-01-18T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0158414000",
#                 "bankCode": "0600",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "102015",
#                 "constantSymbol": "558",
#                 "name": "TYLE ANTON\u00cdN",
#                 "description": "KANAL"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": 1980.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "80110",
#             "dueDate": "2016-01-18T00:00:00",
#             "processingDate": "2016-01-18T00:00:00",
#             "sender": {
#                 "accountNumber": "000051-6424740237",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "65",
#                 "constantSymbol": "558",
#                 "name": "SAIBICOV\u00c1 RADKA"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": 2376.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "80110",
#             "dueDate": "2016-01-18T00:00:00",
#             "processingDate": "2016-01-18T00:00:00",
#             "sender": {
#                 "accountNumber": "000051-2682180297",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "202015",
#                 "constantSymbol": "0",
#                 "name": "PETR RADEK"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": 1584.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "80110",
#             "dueDate": "2016-01-17T00:00:00",
#             "processingDate": "2016-01-17T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-1157669153",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "362015",
#                 "constantSymbol": "0",
#                 "name": "Tl\u00e1\u0161kov\u00e1 Hana"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -3600.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-15T00:00:00",
#             "processingDate": "2016-01-15T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0460025399",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "1600200002",
#                 "constantSymbol": "0308",
#                 "name": "M\u011bsto Veltrusy",
#                 "description": "M\u011bsto Veltrusy - Policie"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -6742.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-15T00:00:00",
#             "processingDate": "2016-01-15T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0002226222",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "6319309437",
#                 "constantSymbol": "0308",
#                 "description": "Pojistn\u00e9 - ro\u010dn\u00ed auto CITROEN JUMPER"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -1500.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-15T00:00:00",
#             "processingDate": "2016-01-15T00:00:00",
#             "sender": {
#                 "accountNumber": "000035-0681470277",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "\u010cSAD - dotace na spoje"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -57605.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "20500",
#             "dueDate": "2016-01-15T00:00:00",
#             "processingDate": "2016-01-15T00:00:00",
#             "sender": {
#                 "accountNumber": "702651-0033105036",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -27940.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "81120",
#             "dueDate": "2016-01-15T00:00:00",
#             "processingDate": "2016-01-15T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0004444442",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "specificSymbol": "7863214135",
#                 "specificSymbolParty": "7863214135",
#                 "variableSymbol": "4132576900",
#                 "constantSymbol": "308",
#                 "name": "\u010cEZ PRODEJ, S.R.O.",
#                 "description": "OBEC NOVA VES       NOVA VES 154NOVA VES"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -65310.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "81120",
#             "dueDate": "2016-01-15T00:00:00",
#             "processingDate": "2016-01-15T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0004444442",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "specificSymbol": "7363378889",
#                 "specificSymbolParty": "7363378889",
#                 "variableSymbol": "4120814100",
#                 "constantSymbol": "308",
#                 "name": "\u010cEZ PRODEJ, S.R.O.",
#                 "description": "OBEC NOVA VES       NOVA VES 154NOVA VES"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": 1584.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "80110",
#             "dueDate": "2016-01-15T00:00:00",
#             "processingDate": "2016-01-15T00:00:00",
#             "sender": {
#                 "accountNumber": "000019-8285360267",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "272015",
#                 "constantSymbol": "308",
#                 "name": "ROUS LUBO\u0160",
#                 "description": "KANALIZACE-2016-1"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": 2376.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "80110",
#             "dueDate": "2016-01-14T00:00:00",
#             "processingDate": "2016-01-14T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-1394120033",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "82015",
#                 "constantSymbol": "0",
#                 "name": "Hainc Richard",
#                 "description": "Z\u00e1loha za kanalizaci               "
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": 1584.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "80110",
#             "dueDate": "2016-01-14T00:00:00",
#             "processingDate": "2016-01-14T00:00:00",
#             "sender": {
#                 "accountNumber": "670100-2200799784",
#                 "bankCode": "6210",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "462015",
#                 "constantSymbol": "0",
#                 "name": "PETR STOREK",
#                 "description": "ODPADN\u00cd VODY - \u0160TORKOVI"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": 3168.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "80110",
#             "dueDate": "2016-01-14T00:00:00",
#             "processingDate": "2016-01-14T00:00:00",
#             "sender": {
#                 "accountNumber": "000107-2525700287",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "402015",
#                 "constantSymbol": "0",
#                 "name": "KA\u0160\u00c1K EMIL",
#                 "description": "EMILKASAK"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": 1584.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "80110",
#             "dueDate": "2016-01-14T00:00:00",
#             "processingDate": "2016-01-14T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0863612053",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "372015",
#                 "constantSymbol": "0",
#                 "name": "Ml\u00e1dkov\u00e1 Kl\u00e1ra",
#                 "description": "sto\u010dn\u00e9 Ml\u00e1dek"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": 6336.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "80110",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0713865063",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "162015",
#                 "constantSymbol": "0",
#                 "name": "Hanouskov\u00e1 Kate\u0159ina"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -10000.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-3961861399",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "22016",
#                 "constantSymbol": "0308",
#                 "name": "MZP Consulting s.r.o.",
#                 "description": "Zpracov\u00e1n\u00ed projektu- d\u011btsk\u00e9 h\u0159i\u0161t\u011bMi\u0159ejovice"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -17040.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "020001-0032721881",
#                 "bankCode": "0710",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "800090962",
#                 "constantSymbol": "0308",
#                 "description": "Institut pro ve\u0159. spr\u00e1vu"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -1690.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "020001-0032721881",
#                 "bankCode": "0710",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "800090963",
#                 "constantSymbol": "0308",
#                 "description": "Institut pro ve\u0159. spr\u00e1vu"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -37389.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000107-8753200257",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "15060",
#                 "constantSymbol": "0308",
#                 "description": "vodohospod\u00e1\u0159 obce - tech. pomoc"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -17000.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-3961861399",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "32016",
#                 "constantSymbol": "0308",
#                 "name": "MZP Consulting s.r.o.",
#                 "description": "V\u00fdb\u011brov\u00e9 \u0159\u00edzen\u00ed"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -28000.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-3961861399",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "12016",
#                 "constantSymbol": "0308",
#                 "name": "MZP Consulting s.r.o.",
#                 "description": "zpracov\u00e1n\u00ed projektu-revitalizace ve\u0159. prostranstv\u00ed"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -6287.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-2100053299",
#                 "bankCode": "2010",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "202016",
#                 "constantSymbol": "0308",
#                 "description": "Pr\u00e1vn\u00ed slu\u017eby"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -2473.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-1207198012",
#                 "bankCode": "3030",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -832.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0110542353",
#                 "bankCode": "0300",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -12585.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0269918711",
#                 "bankCode": "0300",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "mzda"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -1822.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "090034-0017433021",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "3558",
#                 "description": "z\u00e1konn\u00e9 poji\u0161t\u011bn\u00ed"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -26078.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000713-0077628111",
#                 "bankCode": "0710",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "1148",
#                 "description": "F\u00fa .da\u0148 - z\u00e1lohov\u00e1"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -1442.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-1183269014",
#                 "bankCode": "3030",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -18472.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-1025240005",
#                 "bankCode": "2700",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -832.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0873207123",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -2040.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0235352895",
#                 "bankCode": "0300",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "mzda"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -845.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-13T00:00:00",
#             "processingDate": "2016-01-13T00:00:00",
#             "sender": {
#                 "accountNumber": "007720-0077628111",
#                 "bankCode": "0710",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "1148",
#                 "description": "F\u00fa-da\u0148 - sr\u00e1\u017ekov\u00e1"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -205981.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "40047",
#             "dueDate": "2016-01-12T00:00:00",
#             "processingDate": "2016-01-12T00:00:00",
#             "sender": {
#                 "accountNumber": "000027-9328790297",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "154205485",
#                 "constantSymbol": "308"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -73.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-12T00:00:00",
#             "processingDate": "2016-01-12T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-2228800222",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "23713200",
#                 "constantSymbol": "0558",
#                 "description": "Zdr.poj. \u010cesk\u00e1 pr\u016fmyslov\u00e1"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -31061.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-12T00:00:00",
#             "processingDate": "2016-01-12T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0171099295",
#                 "bankCode": "0600",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -9164.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-12T00:00:00",
#             "processingDate": "2016-01-12T00:00:00",
#             "sender": {
#                 "accountNumber": "010006-0018432071",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "3558",
#                 "description": "Zdr.poj. Oborov\u00e1"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -425.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-12T00:00:00",
#             "processingDate": "2016-01-12T00:00:00",
#             "sender": {
#                 "accountNumber": "000035-3491540207",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -53930.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-12T00:00:00",
#             "processingDate": "2016-01-12T00:00:00",
#             "sender": {
#                 "accountNumber": "021012-0007922171",
#                 "bankCode": "0710",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "2255139434",
#                 "constantSymbol": "7618",
#                 "description": "OSSZ m\u011bln\u00edk"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -17748.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-12T00:00:00",
#             "processingDate": "2016-01-12T00:00:00",
#             "sender": {
#                 "accountNumber": "000027-8225200237",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "23713200",
#                 "constantSymbol": "0558",
#                 "description": "Zdr.poj. v\u0161eobecn\u00e1"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -3559.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-12T00:00:00",
#             "processingDate": "2016-01-12T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0004220422",
#                 "bankCode": "0300",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "23713200",
#                 "constantSymbol": "3558",
#                 "description": "zdr.poj.M.V.\u010cR"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -16402.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-12T00:00:00",
#             "processingDate": "2016-01-12T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0154857680",
#                 "bankCode": "0600",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -515.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2016-01-12T00:00:00",
#             "processingDate": "2016-01-12T00:00:00",
#             "sender": {
#                 "accountNumber": "000051-2615250267",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -884.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2017-02-06T00:00:00",
#             "processingDate": "2017-02-06T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0878052183",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "dm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -884.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2017-02-06T00:00:00",
#             "processingDate": "2017-02-06T00:00:00",
#             "sender": {
#                 "accountNumber": "670100-2205603904",
#                 "bankCode": "6210",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "dm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -884.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2017-02-06T00:00:00",
#             "processingDate": "2017-02-06T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-2400206664",
#                 "bankCode": "2010",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -17486.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2017-02-06T00:00:00",
#             "processingDate": "2017-02-06T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-0154857680",
#                 "bankCode": "0600",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -2642.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2017-02-06T00:00:00",
#             "processingDate": "2017-02-06T00:00:00",
#             "sender": {
#                 "accountNumber": "000000-1207198012",
#                 "bankCode": "3030",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         },
#         {
#             "amount": {
#                 "value": -445.0,
#                 "precision": 0,
#                 "currency": "CZK"
#             },
#             "type": "93551",
#             "dueDate": "2017-02-06T00:00:00",
#             "processingDate": "2017-02-06T00:00:00",
#             "sender": {
#                 "accountNumber": "000115-1484640227",
#                 "bankCode": "0100",
#                 "iban": "CZ63 0800 0000 0004 6004 3319",
#                 "variableSymbol": "237132",
#                 "constantSymbol": "0308",
#                 "description": "odm\u011bna"
#             },
#             "receiver": {
#                 "accountNumber": "000000-0460043319",
#                 "bankCode": "0800",
#                 "iban": "CZ63 0800 0000 0004 6004 3319"
#             }
#         }
#     ]
# }
